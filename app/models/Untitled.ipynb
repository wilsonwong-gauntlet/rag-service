# %%
# !which python3
# Out:
# /Users/gauntlet/rag-service/venv/bin/python3

# %%
# !pip3 list
# Out:
# Package                   Version
# ------------------------- --------------
# aiohappyeyeballs          2.4.4
# aiohttp                   3.11.11
# aiosignal                 1.3.2
# amqp                      5.3.1
# annotated-types           0.7.0
# anyio                     3.7.1
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# billiard                  4.2.1
# bleach                    6.2.0
# celery                    5.3.6
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.4.1
# click                     8.1.8
# click-didyoumean          0.3.1
# click-plugins             1.1.1
# click-repl                0.3.0
# comm                      0.2.2
# ...
